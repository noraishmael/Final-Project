# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
y = np.linspace(-1,1,5)
x = np.arange(5) 
y2 = np.linspace (-2,2,5)
fig = plt.figure()
ax = fig.subplots()
line1 = ax.plot(x,y)
line2 = ax.plot(x,y2)

# %%
## having mutiple plot in a figure
number_rows = 3
number_columns = 2

## create a figure
fig2 = plt.figure()

## create subplot
ax2 = fig2.subplots(number_rows, number_columns)

ax2[0,1].plot(x,y)
ax2[1,0].plot(x,y)
ax2[2,1].plot(x,y)

# %%
## basic plotting
y1 = np.arange(0,110,10)
y2 = np.random.random(11)
x1 = np.arange(11)
fig, ax = plt.subplots(2,2)
ax[0,0].plot(x1,y1)
ax[0,1].scatter(x1,y1)
ax[1,0].bar(x1,y1)
ax[1,1].barh(x1,y1)
# Out:
# <BarContainer object of 11 artists>

# %%
## trigonometric function

X = np.arange(0, 4*np.pi, 0.05)
ycos = np.cos(X)
ysin = np.sin(X)
fig, ax = plt.subplots()
ax.plot(X,ycos, 'b-', label = 'cos(X)')
ax.plot(X,ysin,'r--', label = 'sin(X)')

# %%
fig, ax = plt.subplots(1,2)
ax[0].axhline(0.3, color = 'red')
ax[0].axhline(0.4, linestyle = '--', color = 'blue')
ax[0].axhline(0.5, color = 'cyan', linewidth = 10)
ax[0].axhline(0.6, linestyle = ':', xmin = 0.25, xmax = 0.75, color = 'orchid')
ax[0].axhline(0.7, xmin = 0.25, xmax = 0.75, color = (0.1, 0.2, 0.5, 0.3))
ax[0].set_ylim((0.1, 0.9))
ax[0].set_title('Horizontal lines', fontstyle = 'italic')


ax[1].axvline(0.3, color = 'red')
ax[1].axvline(0.4, linestyle = '--', color = 'blue')
ax[1].axvline(0.5, color = 'cyan', linewidth = 10)
ax[1].axvline(0.6, linestyle = ':', ymin = 0.25, ymax = 0.75, color = 'orchid')
ax[1].axvline(0.7, ymin = 0.25, ymax = 0.75, color = (0.1, 0.2, 0.5, 0.3))
ax[1].set_ylim((0.1, 0.9))
ax[1].set_title('Vertical lines', fontstyle = 'italic')
# Out:
# Text(0.5, 1.0, 'Vertical lines')

# %%
## scatter plot
x = np.array([2,4,6,7,4,2,5,7,8,9,4,2,1])
y = np.array([7,5,4,1,6,7,8,1,9,5,9,3,5])
fig, ax = plt.subplots(1,3)
ax[0].scatter(x,y)
ax[0].set_title('Default')
ax[1].scatter(x,y,50, marker = '+')
ax[1].set_title('size = 50, style = +')
crosses = ax[2].scatter(x,y, 200, marker = '+', linewidth = 3)
bullets = ax[2].scatter(x,y, 50, marker = '0', color = 'black')
bullets.set_edgecolors('red')
bullets.set_linewidth(1.5)
ax[2].set_title('mixed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None and len(vertices):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_api\__init__.py:162, in check_shape(shape, **kwargs)
#     160     text_shape += ","
# --> 162 raise ValueError(
#     163     f"{k!r} must be {len(shape)}D with shape ({text_shape}), "
#     164     f"but your input has shape {v.shape}"
#     165 )
#
# ValueError: 'vertices' must be 2D with shape (N, 2), but your input has shape ()
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 10
#       8 ax[1].set_title('size = 50, style = +')
#       9 crosses = ax[2].scatter(x,y, 200, marker = '+', linewidth = 3)
# ---> 10 bullets = ax[2].scatter(x,y, 50, marker = '0', color = 'black')
#      11 bullets.set_edgecolors('red')
#      12 bullets.set_linewidth(1.5)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:4945, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4943     marker_obj = marker
#    4944 else:
# -> 4945     marker_obj = mmarkers.MarkerStyle(marker)
#    4947 path = marker_obj.get_path().transformed(
#    4948     marker_obj.get_transform())
#    4949 if not marker_obj.is_filled():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\markers.py:248, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     246 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     247 self._set_fillstyle(fillstyle)
# --> 248 self._set_marker(marker)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\markers.py:329, in MarkerStyle._set_marker(self, marker)
#     327         self._marker_function = self._set_vertices
#     328     except ValueError as err:
# --> 329         raise ValueError(
#     330             f'Unrecognized marker style {marker!r}') from err
#     332 if not isinstance(marker, MarkerStyle):
#     333     self._marker = marker
#
# ValueError: Unrecognized marker style '0'

# %%
## create a 3d shape

z = np.array([0,1,4,3,5,1,2,5,7,5,9,8,5])
fig = plt.figure()
ax = np.array([fig.add_subplot(1,3,1, projection = '3d'),
               fig.add_subplot(1,3,2, projection = '3d'),
               fig.add_subplot(1,3,3, projection = '3d')])
