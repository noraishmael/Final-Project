# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#import dataset
ED = pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv')

# %%
#define dataframe which is the Earthquake Dataset or ED
df = ED

# %%
#visualise five first lines of the ED with header
df.head(5)
# Out:
#                        time   latitude   longitude   depth  mag magType   nst  \
# 0  2025-01-22T15:27:43.568Z  24.727700   93.100500   10.00  4.5      mb  47.0
# 1  2025-01-22T15:09:50.763Z  59.835200 -152.926000  110.40  2.0      ml   NaN
# 2  2025-01-22T15:05:51.434Z  39.100600 -119.011300    4.80  1.1      ml  13.0
# 3  2025-01-22T14:16:55.620Z  36.026500 -117.774667    1.97  1.0      ml  19.0
# 4  2025-01-22T14:07:39.890Z  38.823666 -122.809669    2.36  0.6      md   7.0
#
#      gap      dmin     rms  ...                   updated  \
# 0  87.00  3.884000  0.8100  ...  2025-01-22T15:47:24.711Z
# 1    NaN       NaN  0.2400  ...  2025-01-22T15:12:04.190Z
# 2  96.14  0.072000  0.1741  ...  2025-01-22T15:08:09.105Z
# 3  66.00  0.007733  0.1500  ...  2025-01-22T14:20:21.721Z
# 4  99.00  0.019280  0.0100  ...  2025-01-22T14:09:17.315Z
#
#                              place        type horizontalError depthError  \
# 0      11 km SE of Lakhipur, India  earthquake            5.83      1.913
# 1  61 km W of Anchor Point, Alaska  earthquake             NaN      0.400
# 2    18 km NE of Yerington, Nevada  earthquake             NaN      1.000
# 3      16 km NE of Little Lake, CA  earthquake            0.23      0.180
# 4      7 km NNW of The Geysers, CA  earthquake            0.66      2.610
#
#    magError  magNst     status  locationSource magSource
# 0     0.099    30.0   reviewed              us        us
# 1       NaN     NaN  automatic              ak        ak
# 2     0.170     7.0  automatic              nn        nn
# 3     0.148    19.0  automatic              ci        ci
# 4     0.320     9.0  automatic              nc        nc
#
# [5 rows x 22 columns]

# %%
#check the type of values
ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8704 entries, 0 to 8703
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             8704 non-null   object
#  1   latitude         8704 non-null   float64
#  2   longitude        8704 non-null   float64
#  3   depth            8704 non-null   float64
#  4   mag              8704 non-null   float64
#  5   magType          8704 non-null   object
#  6   nst              7394 non-null   float64
#  7   gap              7394 non-null   float64
#  8   dmin             7393 non-null   float64
#  9   rms              8702 non-null   float64
#  10  net              8704 non-null   object
#  11  id               8704 non-null   object
#  12  updated          8704 non-null   object
#  13  place            8704 non-null   object
#  14  type             8704 non-null   object
#  15  horizontalError  6554 non-null   float64
#  16  depthError       8703 non-null   float64
#  17  magError         7378 non-null   float64
#  18  magNst           7390 non-null   float64
#  19  status           8704 non-null   object
#  20  locationSource   8704 non-null   object
#  21  magSource        8704 non-null   object
# dtypes: float64(12), object(10)
# memory usage: 1.5+ MB

# %%
#check if there are values missing
ED.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                1310
# gap                1310
# dmin               1311
# rms                   2
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2150
# depthError            1
# magError           1326
# magNst             1314
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
#list the descriptive stats for each of the columns
df.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  8704.000000  8704.000000  8704.000000  8704.000000  7394.000000
# mean     40.292820  -108.252651    18.753226     1.538291    22.607114
# std      18.317014    68.187013    46.682757     1.338060    21.028768
# min     -65.296600  -179.896700    -3.490000    -1.890000     0.000000
# 25%      33.775958  -150.192975     2.237500     0.750000     9.000000
# 50%      38.822498  -121.897917     6.800000     1.330000    15.000000
# 75%      58.166542  -114.382500    12.330000     2.000000    28.000000
# max      75.758100   179.991600   639.916000     7.100000   246.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  7394.000000  7393.000000  8702.000000      6554.000000  8703.000000
# mean    115.743891     0.507231     0.263362         1.832929     2.175382
# std      63.352339     1.909225     0.281641         3.283556     4.745079
# min      13.000000     0.000000     0.000000         0.000000     0.000000
# 25%      68.000000     0.016740     0.080000         0.270000     0.500000
# 50%     102.000000     0.062020     0.160000         0.440000     0.860000
# 75%     146.000000     0.130000     0.330000         1.010000     1.870000
# max     347.000000    50.218000     4.560000        23.890000   111.200000
#
#           magError       magNst
# count  7378.000000  7390.000000
# mean      0.189318    17.537618
# std       0.115605    22.345420
# min       0.000000     0.000000
# 25%       0.117000     7.000000
# 50%       0.174517    11.000000
# 75%       0.233239    21.000000
# max       2.970000   357.000000

# %%
#create a scatterplot showing the coordinates of where each eartquake occurs

x = df["longitude"]
y = df["latitude"]
plt.scatter(x, y, color = 'blue', alpha = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #create a scatterplot showing the coordinates of where each eartquake occurs
# ----> 3 x = df["longitude"]
#       4 y = df["latitude"]
#       5 plt.scatter(x, y, color = 'blue', alpha = 1)
#
# NameError: name 'df' is not defined

# %%
#create a pie chart to show the percentage of the different types of earthquakes occurring
df = ED
t = df["type"]
type_counts = t.value_counts()
mycolors = ["b", "c", "m", "y"]

plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', colors = mycolors)

plt.title("Percentage of Different Types of Earthquakes")
plt.legend(type_counts.index, title="Types of Earthquakes")
plt.show()

# %%
#create a histogram to show the distribution of the magnitude of the earthquakes (i.e. intensity/frequency)
df = ED
m = df["mag"]
plt.hist(m)
plt.title("Distribution of the Magnitude of Earthquakes")
plt.show()

# %%
#test to enhance first graph 
df = ED
x = df["longitude"]
y = df["latitude"]
z = df["mag"]

# Use the 's' parameter to set the size of the markers based on the magnitude
plt.scatter(x, y, s=z*10, color='blue', alpha=0.5)

# Optionally, add labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earthquake Scatterplot')

# Show the plot
plt.show()
